# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
warnings.filterwarnings('ignore')
import missingno as msno
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf

# %%
data = pd.read_csv('/work/menu.csv')
data.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
DeepnoteChart(data, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Cholesterol (% Daily Value)","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"nominal","field":"Item","scale":{"type":"linear"}}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
len(data['Item'].unique())
# Out:
# 260

# %%
data = data[data['Cholesterol (% Daily Value)'] <= 40]

# %%
data
# Out:
#                Category                                               Item  \
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 8             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
DeepnoteChart(data, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Trans Fat","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"nominal","field":"Item","scale":{"type":"linear"}}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
data = data[data['Trans Fat'] <= 1.0]

# %%
data
# Out:
#                Category                                               Item  \
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 8             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9             Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
DeepnoteChart(data, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"quantitative","field":"Sodium (% Daily Value)","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"},"y":{"sort":null,"type":"nominal","field":"Item","scale":{"type":"linear"}}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
data = data[data['Sodium (% Daily Value)'] <= 40]

# %%
data
# Out:
#                Category                                               Item  \
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# 35            Breakfast                                           Hotcakes
# 36            Breakfast                               Hotcakes and Sausage
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
data_Cat_v1= data['Category'].unique().tolist()

# %%
data_Cat
# Out:
# ['Breakfast',
#  'Beef & Pork',
#  'Chicken & Fish',
#  'Salads',
#  'Snacks & Sides',
#  'Desserts',
#  'Beverages',
#  'Coffee & Tea',
#  'Smoothies & Shakes']

# %%
data = data[~data['Category'].isin(['Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes'])]
data
# Out:
#           Category                                            Item  \
# 1        Breakfast                               Egg White Delight
# 2        Breakfast                                Sausage McMuffin
# 4        Breakfast                Sausage McMuffin with Egg Whites
# 35       Breakfast                                        Hotcakes
# 36       Breakfast                            Hotcakes and Sausage
# 37       Breakfast                                 Sausage Burrito
# 38       Breakfast                                      Hash Brown
# 39       Breakfast                                  Cinnamon Melts
# 40       Breakfast                           Fruit & Maple Oatmeal
# 41       Breakfast       Fruit & Maple Oatmeal without Brown Sugar
# 42     Beef & Pork                                         Big Mac
# 48     Beef & Pork                                       Hamburger
# 49     Beef & Pork                                    Cheeseburger
# ...

# %%
data_Cat_v2= data['Category'].unique().tolist()
data_Cat_v2
# Out:
# ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads']

# %%
data
# Out:
#           Category                                            Item  \
# 1        Breakfast                               Egg White Delight
# 2        Breakfast                                Sausage McMuffin
# 4        Breakfast                Sausage McMuffin with Egg Whites
# 35       Breakfast                                        Hotcakes
# 36       Breakfast                            Hotcakes and Sausage
# 37       Breakfast                                 Sausage Burrito
# 38       Breakfast                                      Hash Brown
# 39       Breakfast                                  Cinnamon Melts
# 40       Breakfast                           Fruit & Maple Oatmeal
# 41       Breakfast       Fruit & Maple Oatmeal without Brown Sugar
# 42     Beef & Pork                                         Big Mac
# 48     Beef & Pork                                       Hamburger
# 49     Beef & Pork                                    Cheeseburger
# ...

# %%
DeepnoteChart(data, """{"layer":[{"layer":[{"mark":{"clip":true,"type":"bar","color":"#4c78a8","tooltip":true},"encoding":{"x":{"sort":null,"type":"nominal","field":"Item","scale":{"type":"linear"}},"y":{"sort":null,"type":"quantitative","field":"Total Fat (% Daily Value)","scale":{"type":"linear"},"format":{"type":"default","decimals":null},"aggregate":"sum","formatType":"numberFormatFromNumberType"}}}]}],"title":"","config":{"legend":{}},"$schema":"https://vega.github.io/schema/vega-lite/v5.json","encoding":{}}""")

# %%
data = data[data['Total Fat (% Daily Value)'] <= 20]
data
# Out:
#           Category                                            Item  \
# 1        Breakfast                               Egg White Delight
# 35       Breakfast                                        Hotcakes
# 38       Breakfast                                      Hash Brown
# 40       Breakfast                           Fruit & Maple Oatmeal
# 41       Breakfast       Fruit & Maple Oatmeal without Brown Sugar
# 48     Beef & Pork                                       Hamburger
# 49     Beef & Pork                                    Cheeseburger
# 58  Chicken & Fish        Premium Grilled Chicken Classic Sandwich
# 78  Chicken & Fish                     Chicken McNuggets (4 piece)
# 84          Salads     Premium Bacon Ranch Salad (without Chicken)
# 86          Salads  Premium Bacon Ranch Salad with Grilled Chicken
# 87          Salads       Premium Southwest Salad (without Chicken)
# 89          Salads    Premium Southwest Salad with Grilled Chicken
#
# ...

# %%
data = data.drop([84, 87, 40])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 data = data.drop([84, 87, 40])
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:4308, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4178 def drop(
#    4179     self,
#    4180     labels=None,
#    (...)
#    4186     errors="raise",
#    4187 ):
#    4188     """
#    4189     Drop specified labels from rows or columns.
#    4190
#    (...)
#    4306             weight  1.0     0.8
#    4307     """
# -> 4308     return super().drop(
#    4309         labels=labels,
#    4310         axis=axis,
#    4311         index=index,
#    4312         columns=columns,
#    4313         level=level,
#    4314         inplace=inplace,
#    4315         errors=errors,
#    4316     )
#
# ...

# %%
data = data.drop([40])

# %%
data
# Out:
#           Category                                            Item  \
# 1        Breakfast                               Egg White Delight
# 35       Breakfast                                        Hotcakes
# 38       Breakfast                                      Hash Brown
# 41       Breakfast       Fruit & Maple Oatmeal without Brown Sugar
# 48     Beef & Pork                                       Hamburger
# 49     Beef & Pork                                    Cheeseburger
# 58  Chicken & Fish        Premium Grilled Chicken Classic Sandwich
# 78  Chicken & Fish                     Chicken McNuggets (4 piece)
# 86          Salads  Premium Bacon Ranch Salad with Grilled Chicken
# 89          Salads    Premium Southwest Salad with Grilled Chicken
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 1    4.8 oz (135 g)       250                 70        8.0
# 35   5.3 oz (151 g)       350                 80        9.0
# ...

# %%
data = data.drop([38, 35, 41, 78])

# %%
data
# Out:
#           Category                                            Item  \
# 1        Breakfast                               Egg White Delight
# 48     Beef & Pork                                       Hamburger
# 49     Beef & Pork                                    Cheeseburger
# 58  Chicken & Fish        Premium Grilled Chicken Classic Sandwich
# 86          Salads  Premium Bacon Ranch Salad with Grilled Chicken
# 89          Salads    Premium Southwest Salad with Grilled Chicken
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 1    4.8 oz (135 g)       250                 70        8.0
# 48    3.5 oz (98 g)       240                 70        8.0
# 49     4 oz (113 g)       290                100       11.0
# 58     7 oz (200 g)       350                 80        9.0
# 86   8.5 oz (241 g)       220                 80        8.0
# 89  11.8 oz (335 g)       290                 80        8.0
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a12c740c-40b2-4127-80d3-74d735fad958' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
